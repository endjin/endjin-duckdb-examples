# %%
import duckdb
from pathlib import Path
import arrow

from data_importers import LandRegistryImporter

# %%
TODAY_YEAR = arrow.now().year

# %%
# Load last 3 years of data up to and including the current year

lri = LandRegistryImporter(years_to_import=range(TODAY_YEAR - 2, TODAY_YEAR + 1),)
lri.import_yearly_data()

# %%
DUCKLAKE_FOLDER = Path("../ducklake_land_registry")
if not DUCKLAKE_FOLDER.exists():
    DUCKLAKE_FOLDER.mkdir()

# %%
duckdb.sql("INSTALL ducklake")

# %%
ducklake_metadata = DUCKLAKE_FOLDER / "metadata.ducklake_land_registry"

# %%
duckdb.sql(f"ATTACH 'ducklake:{ducklake_metadata}' AS ducklake_land_registry;")

# %%
duckdb.sql(
    f"""
    CREATE TABLE IF NOT EXISTS ducklake_land_registry.price_paid_raw AS
    SELECT
    column00 AS 'id',
    column01 AS 'price',
    column02 AS 'date',
    column03 AS 'postcode',
    column04 AS 'property_type',
    column05 AS 'old_new',
    column06 AS 'duration',
    column07 AS 'paon',
    column08 AS 'saon',
    column09 AS 'street',
    column10 AS 'locale',
    column11 AS 'town_city',
    column12 AS 'district',
    column13 AS 'county',
    column14 AS 'ppd_category',
    column15 AS 'record_type',
    FROM read_csv('{lri.DATA_FOLDER}/pp-2010.csv');
    """
)

# %%
duckdb.sql(
    f"""
    SELECT * FROM ducklake_land_registry.price_paid_raw;
    """
)
# Out:
# ┌────────────────────────────────────────┬────────┬─────────────────────┬──────────┬───────────────┬─────────┬──────────┬──────────────────┬─────────┬────────────────────┬─────────────────┬──────────────┬──────────────────────────┬──────────────────────────┬──────────────┬─────────────┐
# │                   id                   │ price  │        date         │ postcode │ property_type │ old_new │ duration │       paon       │  saon   │       street       │     locale      │  town_city   │         district         │          county          │ ppd_category │ record_type │
# │                varchar                 │ int64  │      timestamp      │ varchar  │    varchar    │ varchar │ varchar  │     varchar      │ varchar │      varchar       │     varchar     │   varchar    │         varchar          │         varchar          │   varchar    │   varchar   │
# ├────────────────────────────────────────┼────────┼─────────────────────┼──────────┼───────────────┼─────────┼──────────┼──────────────────┼─────────┼────────────────────┼─────────────────┼──────────────┼──────────────────────────┼──────────────────────────┼──────────────┼─────────────┤
# │ {410AB134-347C-4849-A1B5-BF6B79359B68} │  96000 │ 2010-07-27 00:00:00 │ YO25 5BA │ S             │ N       │ F        │ 24               │ NULL    │ MILL FALLS         │ NULL            │ DRIFFIELD    │ EAST RIDING OF YORKSHIRE │ EAST RIDING OF YORKSHIRE │ A            │ A           │
# │ {7611EBB1-F1CA-492A-9967-BF6B8689D6A3} │  90000 │ 2010-10-01 00:00:00 │ B13 9XN  │ F             │ N       │ L        │ ROBERT COURT     │ FLAT 5  │ WAKE GREEN PARK    │ MOSELEY         │ BIRMINGHAM   │ BIRMINGHAM               │ WEST MIDLANDS            │ A            │ A           │
# │ {A75FCB8E-C644-4BD9-B14A-BF6B8EB670F0} │  47000 │ 2010-06-11 00:00:00 │ DN21 1LH │ T             │ N       │ F        │ 57               │ NULL    │ LEA ROAD           │ NULL            │ GAINSBOROUGH │ WEST LINDSEY             │ LINCOLNSHIRE             │ A            │ A           │
# │ {258DCC1E-DD21-45C9-84F4-B856194B5F99} │  90000 │ 2010-05-21 00:00:00 │ NP19 7BE │ T             │ N       │ F        │ 6                │ NULL    │ USK STREET         │ NULL            │ NEWPORT      │ NEWPORT                  │ NEWPORT                  │ A            │ A           │
# │ {8AA9CBDB-A7BA-4E16-BEF6-B856258B98FA} │ 240000 │ 2010-07-28 00:00:00 │ UB5 5JN  │ T             │ N       │ F        │ 14               │ NULL    │ VANBROUGH CRESCENT │ NULL            │ NORTHOLT     │ EALING                   │ GREATER LONDON           │ A            │ A           │
# │ {B553719C-457A-40C2-931F-B8564790C6C8} │ 147000 │ 2010-08-25 00:00:00 │ DE55 3BA │ T             │ N       │ F        │ 31               │ NULL    │ THE BROCKWELL      │ SOUTH NORMANTON │ ALFRETON     │ BOLSOVER                 │ DERBYSHIRE               │ A            │ A           │
# │ {93548E3A-1E1C-4655-9573-C2F19619D181} │  90000 │ 2010-06-21 00:00:00 │ PE1 5AL  │ S             │ N       │ F        │ 20               │ NULL    │ HEREWARD ROAD      │ NULL            │ PETERBOROUGH │ CITY OF PETERBOROUGH     │ CITY OF PETERBOROUGH     │ A            │ A           │
# │ {60CB04B9-37D9-465D-A4B5-C2F1AA68ED49} │ 178000 │ 2010-07-16 00:00:00 │ OX18 1DZ │ D             │ N       │ F        │ 4                │ NULL    │ BURSWIN ROAD       │ NULL            │ CARTERTON    │ WEST OXFORDSHIRE         │ OXFORDSHIRE              │ A            │ A           │
# │ {2CA03BC5-A675-427A-A423-C2F1BB9BB24D} │ 125000 │ 2010-11-26 00:00:00 │ PR6 8QX  │ T             │ N       │ F        │ 3                │ NULL    │ WELL LANE          │ BRINSCALL       │ CHORLEY      │ CHORLEY                  │ LANCASHIRE               │ A            │ A           │
# │ {2273A7D0-426D-42C7-B2DC-C679B3C8E198} │ 462500 │ 2010-04-23 00:00:00 │ SK11 0HJ │ D             │ N       │ F        │ LANGDALE         │ NULL    │ JARMAN ROAD        │ SUTTON          │ MACCLESFIELD │ CHESHIRE EAST            │ CHESHIRE EAST            │ A            │ A           │
# │                   ·                    │    ·   │          ·          │    ·     │ ·             │ ·       │ ·        │ ·                │  ·      │      ·             │  ·              │    ·         │    ·                     │    ·                     │ ·            │ ·           │
# │                   ·                    │    ·   │          ·          │    ·     │ ·             │ ·       │ ·        │ ·                │  ·      │      ·             │  ·              │    ·         │    ·                     │    ·                     │ ·            │ ·           │
# │                   ·                    │    ·   │          ·          │    ·     │ ·             │ ·       │ ·        │ ·                │  ·      │      ·             │  ·              │    ·         │    ·                     │    ·                     │ ·            │ ·           │
# │ {7475F7D5-189D-4892-A6FD-9E86DBF6B9A8} │ 285000 │ 2010-12-03 00:00:00 │ IP4 2TU  │ T             │ Y       │ F        │ 5                │ NULL    │ GROSVENOR CLOSE    │ NULL            │ IPSWICH      │ IPSWICH                  │ SUFFOLK                  │ A            │ A           │
# │ {D4B8C679-F42D-4EEB-B078-9E86DE24CACA} │ 450000 │ 2010-07-23 00:00:00 │ LA12 7JW │ D             │ N       │ F        │ BEECH HOUSE, 11A │ NULL    │ FORD PARK CRESCENT │ NULL            │ ULVERSTON    │ SOUTH LAKELAND           │ CUMBRIA                  │ A            │ A           │
# │ {0F6D0FE8-5D5D-48C1-9DE2-A21AF74DA979} │ 174000 │ 2010-09-10 00:00:00 │ PL12 6DE │ S             │ N       │ F        │ 15               │ NULL    │ TAVY ROAD          │ NULL            │ SALTASH      │ CORNWALL                 │ CORNWALL                 │ A            │ A           │
# │ {EE1BE526-AAFC-430E-BC30-A21B0B173071} │ 340000 │ 2010-11-05 00:00:00 │ CM15 0XA │ D             │ N       │ F        │ 22               │ NULL    │ RODING DRIVE       │ KELVEDON HATCH  │ BRENTWOOD    │ BRENTWOOD                │ ESSEX                    │ A            │ A           │
# │ {82050A14-B955-4F06-8469-A21B163CACF4} │ 235000 │ 2010-09-16 00:00:00 │ UB9 6RB  │ T             │ N       │ F        │ 7                │ NULL    │ DEXTER ROAD        │ HAREFIELD       │ UXBRIDGE     │ HILLINGDON               │ GREATER LONDON           │ A            │ A           │
# │ {58803A51-48D2-45A1-9D69-97635899F32E} │ 175000 │ 2010-01-13 00:00:00 │ CM2 9ED  │ T             │ N       │ F        │ 12               │ NULL    │ MOSS WALK          │ NULL            │ CHELMSFORD   │ CHELMSFORD               │ ESSEX                    │ A            │ A           │
# │ {31436223-8556-4E95-9A7D-976365A332A1} │ 230000 │ 2010-07-28 00:00:00 │ SK8 2DT  │ S             │ N       │ F        │ 8                │ NULL    │ CUTHBERT ROAD      │ NULL            │ CHEADLE      │ STOCKPORT                │ GREATER MANCHESTER       │ A            │ A           │
# │ {467D5D79-3907-4BDD-8120-97636FA58F83} │ 243500 │ 2010-09-24 00:00:00 │ B62 0JS  │ S             │ N       │ F        │ 221              │ NULL    │ BROMSGROVE ROAD    │ HUNNINGTON      │ HALESOWEN    │ BROMSGROVE               │ WORCESTERSHIRE           │ A            │ A           │
# │ {05696FC1-337B-48B6-9F55-9AF70515E518} │  68000 │ 2010-10-07 00:00:00 │ DH7 7LN  │ S             │ N       │ F        │ 8                │ NULL    │ OAKRIDGE ROAD      │ USHAW MOOR      │ DURHAM       │ COUNTY DURHAM            │ COUNTY DURHAM            │ A            │ A           │
# │ {0077D61B-E57A-4A36-8565-93E7D6D818F2} │  90000 │ 2010-10-28 00:00:00 │ CF82 7NG │ S             │ N       │ F        │ 4                │ NULL    │ HENGOED PARC       │ NULL            │ HENGOED      │ CAERPHILLY               │ CAERPHILLY               │ A            │ A           │
# ├────────────────────────────────────────┴────────┴─────────────────────┴──────────┴───────────────┴─────────┴──────────┴──────────────────┴─────────┴────────────────────┴─────────────────┴──────────────┴──────────────────────────┴──────────────────────────┴──────────────┴─────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                    16 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
duckdb.sql(
    f"""
    FROM glob('{ducklake_metadata}.files/*');
    """
)
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │                                                             file                                                             │
# │                                                           varchar                                                            │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-0197133c-04e3-7154-aca1-a3ec165fcdcd.parquet        │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-0197133f-5588-7920-97b1-4f351b6fb278.parquet        │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-01971343-e0c6-7576-afe0-5f695902d4c4.parquet        │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-0197134f-b146-7131-96f6-f4d54eac4de2.parquet        │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-01971367-ce03-7959-bbb7-18f1c04eb9d9.parquet        │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-01971367-dcc1-7634-8e01-f403411ff7bd.parquet        │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-0197136f-e6f5-74e2-bda5-afd24b378f1a.parquet        │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-0197136f-edd1-7f07-bd27-2e09a19027dd-delete.parquet │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-01971373-1294-7ba8-80d1-843d24d7b57d-delete.parquet │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-01971373-129a-7ff3-b6ae-19b6e9f237cf-delete.parquet │
# │                                                              ·                                                               │
# │                                                              ·                                                               │
# │                                                              ·                                                               │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-01974668-e68e-7a3f-a1dd-e4420f5f860d-delete.parquet │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-01974668-e697-73dd-8b85-10c91d07f09b-delete.parquet │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-01974668-e6a0-73a5-80cf-d8413d14e375-delete.parquet │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-01974668-e6a8-72de-a0e6-2415fdc6597a-delete.parquet │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-01974668-e6b2-71d8-bdba-cf4c8c0bd5c6-delete.parquet │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-01974668-e6ba-7e81-b9d1-689f9c917a69-delete.parquet │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-01974668-e6e0-799e-8dcd-f4a54def9b11.parquet        │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-019746d0-6d26-7399-8f68-1510f18183da.parquet        │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-0197844d-d595-74e0-92a8-f62a757cf281.parquet        │
# │ ../ducklake_land_registry/metadata.ducklake_land_registry.files/ducklake-0197844d-d695-75bd-87cb-e7987c972d9e.parquet        │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                                                      28 rows (20 shown)                                                      │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # Process monthly updates
#
# Here the monthly updates utilises the "record_type" column where:
#
# - a = add as a new record
# - c = change / update existing record
# - d = delete

# %%
lri.import_monthly_update()

# %%
duckdb.sql(
    f"""
    DROP TABLE IF EXISTS ducklake_land_registry.monthly_updates;
    CREATE TABLE IF NOT EXISTS ducklake_land_registry.monthly_updates AS
    SELECT
    column00 AS 'id',
    column01 AS 'price',
    column02 AS 'date',
    column03 AS 'postcode',
    column04 AS 'property_type',
    column05 AS 'old_new',
    column06 AS 'duration',
    column07 AS 'paon',
    column08 AS 'saon',
    column09 AS 'street',
    column10 AS 'locale',
    column11 AS 'town_city',
    column12 AS 'district',
    column13 AS 'county',
    column14 AS 'ppd_category',
    column15 AS 'record_type',
    FROM read_csv('{lri.DATA_FOLDER}/{lri.MONTHLY_UPDATE_FILE_NAME}');
    """
)

# %%
duckdb.sql(
    f"""
    SELECT record_type, COUNT(*)
    FROM ducklake_land_registry.monthly_updates
    GROUP BY record_type;
    """
)
# Out:
# ┌─────────────┬──────────────┐
# │ record_type │ count_star() │
# │   varchar   │    int64     │
# ├─────────────┼──────────────┤
# │ A           │        89969 │
# │ D           │         1767 │
# │ C           │         2512 │
# └─────────────┴──────────────┘

# %%
duckdb.sql(
    f"""
    INSERT INTO ducklake_land_registry.price_paid_raw
    SELECT * FROM ducklake_land_registry.monthly_updates
    WHERE record_type = 'A';
    """
)

# %%
duckdb.sql(
    f"""
    DELETE FROM ducklake_land_registry.price_paid_raw
    WHERE id IN (SELECT id FROM ducklake_land_registry.monthly_updates WHERE record_type = 'D');
    """
)

# %% [markdown]
# Unfortunately the following approach generates a `Not Implemented Error`:

# %%
try:
    duckdb.sql(
        f"""
        UPDATE ducklake_land_registry.price_paid_raw
        SET
            price = mu.price,
            date = mu.date,
            postcode = mu.postcode,
            property_type = mu.property_type,
            old_new = mu.old_new,
            duration = mu.duration,
            paon = mu.paon,
            saon = mu.saon,
            street = mu.street,
            locale = mu.locale,
            town_city = mu.town_city,
            district = mu.district,
            county = mu.county,
            ppd_category = mu.ppd_category,
            record_type = mu.record_type
        FROM ducklake_land_registry.monthly_updates AS mu
        WHERE ducklake_land_registry.price_paid_raw.id = mu.id AND mu.record_type = 'C';
        """
    )
except Exception as e:
    print(e)
# Out:
# Not implemented Error: Complex update plans are not yet supported for updates in DuckLake

# %% [markdown]
# So adopt a delete and then insert approach.

# %%
duckdb.sql(
    f"""
    DELETE FROM ducklake_land_registry.price_paid_raw
    WHERE id IN (SELECT id FROM ducklake_land_registry.monthly_updates WHERE record_type = 'C');
    """
)

# %%
duckdb.sql(
    f"""
    INSERT INTO ducklake_land_registry.price_paid_raw
    SELECT * FROM ducklake_land_registry.monthly_updates
    WHERE record_type = 'C';
    """
)

# %%
duckdb.sql(
    f"""
    FROM ducklake_snapshots('ducklake_land_registry');
    """
)
# Out:
# ┌─────────────┬────────────────────────────┬────────────────┬───────────────────────────────────────────────────────────────────┐
# │ snapshot_id │       snapshot_time        │ schema_version │                              changes                              │
# │    int64    │  timestamp with time zone  │     int64      │                      map(varchar, varchar[])                      │
# ├─────────────┼────────────────────────────┼────────────────┼───────────────────────────────────────────────────────────────────┤
# │           0 │ 2025-05-27 19:33:01.536+00 │              0 │ {schemas_created=[main]}                                          │
# │           1 │ 2025-05-27 19:33:09.627+00 │              1 │ {tables_created=[main.price_paid_raw], tables_inserted_into=[1]}  │
# │           2 │ 2025-05-27 19:36:46.91+00  │              1 │ {tables_inserted_into=[1]}                                        │
# │           3 │ 2025-05-27 19:41:44.832+00 │              1 │ {tables_inserted_into=[1]}                                        │
# │           4 │ 2025-05-27 19:54:39.1+00   │              1 │ {tables_inserted_into=[1]}                                        │
# │           5 │ 2025-05-27 20:20:59.262+00 │              2 │ {tables_created=[main.monthly_updates], tables_inserted_into=[2]} │
# │           6 │ 2025-05-27 20:21:03.044+00 │              3 │ {tables_dropped=[2]}                                              │
# │           7 │ 2025-05-27 20:21:03.073+00 │              4 │ {tables_created=[main.monthly_updates], tables_inserted_into=[3]} │
# │           8 │ 2025-05-27 20:29:50.184+00 │              4 │ {tables_inserted_into=[1]}                                        │
# │           9 │ 2025-05-27 20:29:51.732+00 │              4 │ {tables_deleted_from=[1]}                                         │
# │           · │             ·              │              · │             ·                                                     │
# │           · │             ·              │              · │             ·                                                     │
# │           · │             ·              │              · │             ·                                                     │
# │          17 │ 2025-06-06 18:02:49.433+00 │              6 │ {tables_inserted_into=[1]}                                        │
# │          18 │ 2025-06-06 19:55:54.003+00 │              6 │ {tables_inserted_into=[1]}                                        │
# │          19 │ 2025-06-18 18:29:42.667+00 │              7 │ {tables_dropped=[4]}                                              │
# │          20 │ 2025-06-18 18:29:42.682+00 │              8 │ {tables_created=[main.monthly_updates], tables_inserted_into=[5]} │
# │          21 │ 2025-06-18 18:29:43.183+00 │              8 │ {tables_inserted_into=[1]}                                        │
# │          22 │ 2025-06-25 11:12:32.31+00  │              9 │ {tables_dropped=[5]}                                              │
# │          23 │ 2025-06-25 11:12:32.328+00 │             10 │ {tables_created=[main.monthly_updates], tables_inserted_into=[6]} │
# │          24 │ 2025-06-25 11:12:32.733+00 │             10 │ {tables_inserted_into=[1]}                                        │
# │          25 │ 2025-06-25 11:12:33.437+00 │             10 │ {tables_deleted_from=[1]}                                         │
# │          26 │ 2025-06-25 11:12:33.766+00 │             10 │ {tables_inserted_into=[1]}                                        │
# ├─────────────┴────────────────────────────┴────────────────┴───────────────────────────────────────────────────────────────────┤
# │ 27 rows (20 shown)                                                                                                  4 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
