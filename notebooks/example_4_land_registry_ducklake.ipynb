# %%
import duckdb
from pathlib import Path
import arrow

from data_importers import LandRegistryImporter

# %%
TODAY_YEAR = arrow.now().year
LAST_YEAR = TODAY_YEAR - 1

# %%
# Load last 3 years of data up to and including the current year

lri = LandRegistryImporter(years_to_import=range(TODAY_YEAR - 2, TODAY_YEAR + 1),)
lri.import_yearly_data()

# %%
DUCKLAKE_FOLDER = Path("../ducklake_land_registry")
if not DUCKLAKE_FOLDER.exists():
    DUCKLAKE_FOLDER.mkdir()

# %%
duckdb.sql("INSTALL ducklake")

# %%
ducklake_metadata = DUCKLAKE_FOLDER / "metadata.ducklake_land_registry"

# %%
duckdb.sql(f"ATTACH 'ducklake:{ducklake_metadata}' AS ducklake_land_registry;")

# %%
duckdb.sql(
    f"""
    CREATE TABLE IF NOT EXISTS ducklake_land_registry.price_paid_raw AS
    SELECT
    column00 AS 'id',
    column01 AS 'price',
    column02 AS 'date',
    column03 AS 'postcode',
    column04 AS 'property_type',
    column05 AS 'old_new',
    column06 AS 'duration',
    column07 AS 'paon',
    column08 AS 'saon',
    column09 AS 'street',
    column10 AS 'locale',
    column11 AS 'town_city',
    column12 AS 'district',
    column13 AS 'county',
    column14 AS 'ppd_category',
    column15 AS 'record_type',
    FROM read_csv('{lri.DATA_FOLDER}/pp-{LAST_YEAR}.csv');
    """
)

# %%
duckdb.sql(
    f"""
    SELECT * FROM ducklake_land_registry.price_paid_raw;
    """
)
# Out:
# ┌────────────────────────────────────────┬────────┬─────────────────────┬──────────┬───────────────┬─────────┬──────────┬──────────────────────┬─────────┬────────────────────┬──────────────┬────────────────┬────────────────────────┬────────────────────────┬──────────────┬─────────────┐
# │                   id                   │ price  │        date         │ postcode │ property_type │ old_new │ duration │         paon         │  saon   │       street       │    locale    │   town_city    │        district        │         county         │ ppd_category │ record_type │
# │                varchar                 │ int64  │      timestamp      │ varchar  │    varchar    │ varchar │ varchar  │       varchar        │ varchar │      varchar       │   varchar    │    varchar     │        varchar         │        varchar         │   varchar    │   varchar   │
# ├────────────────────────────────────────┼────────┼─────────────────────┼──────────┼───────────────┼─────────┼──────────┼──────────────────────┼─────────┼────────────────────┼──────────────┼────────────────┼────────────────────────┼────────────────────────┼──────────────┼─────────────┤
# │ {2131FCF6-4B5B-86E8-E063-4804A8C0372B} │ 395000 │ 2024-08-15 00:00:00 │ NR18 0EA │ D             │ N       │ F        │ 16                   │ NULL    │ GAYNOR CLOSE       │ NULL         │ WYMONDHAM      │ SOUTH NORFOLK          │ NORFOLK                │ A            │ A           │
# │ {2131FCF6-4E70-86E8-E063-4804A8C0372B} │ 275000 │ 2024-08-07 00:00:00 │ NN3 2JW  │ T             │ N       │ F        │ 125                  │ NULL    │ BEECH AVENUE       │ NULL         │ NORTHAMPTON    │ WEST NORTHAMPTONSHIRE  │ WEST NORTHAMPTONSHIRE  │ A            │ A           │
# │ {2131FCF6-4E71-86E8-E063-4804A8C0372B} │ 157500 │ 2024-08-01 00:00:00 │ NN4 5DA  │ F             │ N       │ L        │ 11                   │ NULL    │ MEADOWSWEET WALK   │ GRANGE PARK  │ NORTHAMPTON    │ WEST NORTHAMPTONSHIRE  │ WEST NORTHAMPTONSHIRE  │ A            │ A           │
# │ {2131FCF6-4E72-86E8-E063-4804A8C0372B} │ 210000 │ 2024-03-22 00:00:00 │ NN16 9FA │ S             │ N       │ F        │ 37                   │ NULL    │ PENDLE AVENUE      │ NULL         │ KETTERING      │ NORTH NORTHAMPTONSHIRE │ NORTH NORTHAMPTONSHIRE │ A            │ A           │
# │ {2131FCF6-4E73-86E8-E063-4804A8C0372B} │ 260000 │ 2024-07-26 00:00:00 │ NN5 7PR  │ T             │ N       │ F        │ 50                   │ NULL    │ NENE PLACE         │ NULL         │ NORTHAMPTON    │ WEST NORTHAMPTONSHIRE  │ WEST NORTHAMPTONSHIRE  │ A            │ A           │
# │ {2131FCF6-4E74-86E8-E063-4804A8C0372B} │ 500000 │ 2024-08-14 00:00:00 │ NN14 1GJ │ D             │ N       │ F        │ 79                   │ NULL    │ OLD GORSE WAY      │ MAWSLEY      │ KETTERING      │ NORTH NORTHAMPTONSHIRE │ NORTH NORTHAMPTONSHIRE │ A            │ A           │
# │ {2131FCF6-4E75-86E8-E063-4804A8C0372B} │ 175000 │ 2024-07-31 00:00:00 │ NN1 3BA  │ F             │ N       │ L        │ CHURCH'S FACTORY, 10 │ FLAT 10 │ DUKE STREET        │ NULL         │ NORTHAMPTON    │ WEST NORTHAMPTONSHIRE  │ WEST NORTHAMPTONSHIRE  │ A            │ A           │
# │ {2131FCF6-4E76-86E8-E063-4804A8C0372B} │ 262000 │ 2024-08-09 00:00:00 │ NN3 6AG  │ S             │ N       │ F        │ 11                   │ NULL    │ BIBURY CRESCENT    │ NULL         │ NORTHAMPTON    │ WEST NORTHAMPTONSHIRE  │ WEST NORTHAMPTONSHIRE  │ A            │ A           │
# │ {2131FCF6-4E77-86E8-E063-4804A8C0372B} │ 350000 │ 2024-08-01 00:00:00 │ NN11 9YS │ D             │ N       │ F        │ 42                   │ NULL    │ DEWAR DRIVE        │ NULL         │ DAVENTRY       │ WEST NORTHAMPTONSHIRE  │ WEST NORTHAMPTONSHIRE  │ A            │ A           │
# │ {2131FCF6-4E78-86E8-E063-4804A8C0372B} │ 235000 │ 2024-04-22 00:00:00 │ NN15 7RQ │ D             │ N       │ F        │ 17                   │ NULL    │ GRANT CLOSE        │ NULL         │ KETTERING      │ NORTH NORTHAMPTONSHIRE │ NORTH NORTHAMPTONSHIRE │ B            │ A           │
# │                   ·                    │    ·   │          ·          │    ·     │ ·             │ ·       │ ·        │ ·                    │  ·      │      ·             │  ·           │    ·           │     ·                  │      ·                 │ ·            │ ·           │
# │                   ·                    │    ·   │          ·          │    ·     │ ·             │ ·       │ ·        │ ·                    │  ·      │      ·             │  ·           │    ·           │     ·                  │      ·                 │ ·            │ ·           │
# │                   ·                    │    ·   │          ·          │    ·     │ ·             │ ·       │ ·        │ ·                    │  ·      │      ·             │  ·           │    ·           │     ·                  │      ·                 │ ·            │ ·           │
# │ {36A61A95-286D-DEF2-E063-4704A8C046AE} │ 635000 │ 2024-05-10 00:00:00 │ RH10 4BG │ D             │ Y       │ F        │ 7                    │ NULL    │ WYCHWOOD GREEN     │ CRAWLEY DOWN │ CRAWLEY        │ MID SUSSEX             │ WEST SUSSEX            │ A            │ A           │
# │ {36A61A95-286E-DEF2-E063-4704A8C046AE} │ 245000 │ 2024-04-24 00:00:00 │ RH16 3AJ │ F             │ Y       │ L        │ CHURCH CORNER HOUSE  │ FLAT 19 │ CHURCH ROAD        │ NULL         │ HAYWARDS HEATH │ MID SUSSEX             │ WEST SUSSEX            │ A            │ A           │
# │ {36A61A95-286F-DEF2-E063-4704A8C046AE} │ 400000 │ 2024-05-24 00:00:00 │ RH20 4HT │ D             │ N       │ F        │ KITHURST COTTAGES    │ 1       │ KITHURST FARM ROAD │ STORRINGTON  │ PULBOROUGH     │ HORSHAM                │ WEST SUSSEX            │ A            │ A           │
# │ {36A61A95-2870-DEF2-E063-4704A8C046AE} │ 380000 │ 2024-05-31 00:00:00 │ RH17 6UR │ S             │ N       │ F        │ EAST COTTAGE         │ NULL    │ CHURCH LANE        │ ARDINGLY     │ HAYWARDS HEATH │ MID SUSSEX             │ WEST SUSSEX            │ A            │ A           │
# │ {36A61A95-2872-DEF2-E063-4704A8C046AE} │ 395000 │ 2024-03-28 00:00:00 │ RH10 3YQ │ T             │ Y       │ F        │ 47                   │ NULL    │ PAYNE WAY          │ COPTHORNE    │ CRAWLEY        │ CRAWLEY                │ WEST SUSSEX            │ A            │ A           │
# │ {36A61A95-2873-DEF2-E063-4704A8C046AE} │ 225000 │ 2024-06-07 00:00:00 │ BN15 9WW │ F             │ N       │ L        │ THE PRESBYTERY, 127  │ FLAT 4  │ NORTH ROAD         │ NULL         │ LANCING        │ ADUR                   │ WEST SUSSEX            │ A            │ A           │
# │ {36A61A95-2874-DEF2-E063-4704A8C046AE} │ 610000 │ 2024-02-23 00:00:00 │ RH10 2BF │ D             │ Y       │ F        │ 11                   │ NULL    │ REED DRIVE         │ COPTHORNE    │ CRAWLEY        │ CRAWLEY                │ WEST SUSSEX            │ A            │ A           │
# │ {36A61A95-2875-DEF2-E063-4704A8C046AE} │ 472000 │ 2024-05-14 00:00:00 │ BN44 3FJ │ S             │ N       │ F        │ 29                   │ NULL    │ KINGS STONE AVENUE │ NULL         │ STEYNING       │ HORSHAM                │ WEST SUSSEX            │ A            │ A           │
# │ {36A61A95-2876-DEF2-E063-4704A8C046AE} │ 375000 │ 2024-05-24 00:00:00 │ BN14 7JX │ S             │ N       │ F        │ 18                   │ NULL    │ TWITTEN WAY        │ NULL         │ WORTHING       │ WORTHING               │ WEST SUSSEX            │ A            │ A           │
# │ {36A61A95-2877-DEF2-E063-4704A8C046AE} │ 245000 │ 2024-06-12 00:00:00 │ BN18 0YW │ F             │ N       │ F        │ 12                   │ NULL    │ HERMITAGE LANE     │ FONTWELL     │ ARUNDEL        │ ARUN                   │ WEST SUSSEX            │ A            │ A           │
# ├────────────────────────────────────────┴────────┴─────────────────────┴──────────┴───────────────┴─────────┴──────────┴──────────────────────┴─────────┴────────────────────┴──────────────┴────────────────┴────────────────────────┴────────────────────────┴──────────────┴─────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                   16 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
duckdb.sql(
    f"""
    FROM glob('{ducklake_metadata}.files/*');
    """
)
# Out:
# ┌─────────┐
# │  file   │
# │ varchar │
# ├─────────┤
# │ 0 rows  │
# └─────────┘

# %% [markdown]
# # Process monthly updates
#
# Here the monthly updates utilises the "record_type" column where:
#
# - a = add as a new record
# - c = change / update existing record
# - d = delete

# %%
lri.import_monthly_update()

# %%
duckdb.sql(
    f"""
    DROP TABLE IF EXISTS ducklake_land_registry.monthly_updates;
    CREATE TABLE IF NOT EXISTS ducklake_land_registry.monthly_updates AS
    SELECT
    column00 AS 'id',
    column01 AS 'price',
    column02 AS 'date',
    column03 AS 'postcode',
    column04 AS 'property_type',
    column05 AS 'old_new',
    column06 AS 'duration',
    column07 AS 'paon',
    column08 AS 'saon',
    column09 AS 'street',
    column10 AS 'locale',
    column11 AS 'town_city',
    column12 AS 'district',
    column13 AS 'county',
    column14 AS 'ppd_category',
    column15 AS 'record_type',
    FROM read_csv('{lri.DATA_FOLDER}/{lri.MONTHLY_UPDATE_FILE_NAME}');
    """
)

# %%
duckdb.sql(
    f"""
    SELECT record_type, COUNT(*)
    FROM ducklake_land_registry.monthly_updates
    GROUP BY record_type;
    """
)
# Out:
# ┌─────────────┬──────────────┐
# │ record_type │ count_star() │
# │   varchar   │    int64     │
# ├─────────────┼──────────────┤
# │ C           │         2751 │
# │ D           │         1994 │
# │ A           │       101000 │
# └─────────────┴──────────────┘

# %%
duckdb.sql(
    f"""
    INSERT INTO ducklake_land_registry.price_paid_raw
    SELECT * FROM ducklake_land_registry.monthly_updates
    WHERE record_type = 'A';
    """
)

# %%
duckdb.sql(
    f"""
    DELETE FROM ducklake_land_registry.price_paid_raw
    WHERE id IN (SELECT id FROM ducklake_land_registry.monthly_updates WHERE record_type = 'D');
    """
)

# %% [markdown]
# Unfortunately the following approach generates a `Not Implemented Error`:

# %%
duckdb.sql(
    f"""
    UPDATE ducklake_land_registry.price_paid_raw
    SET
        price = mu.price,
        date = mu.date,
        postcode = mu.postcode,
        property_type = mu.property_type,
        old_new = mu.old_new,
        duration = mu.duration,
        paon = mu.paon,
        saon = mu.saon,
        street = mu.street,
        locale = mu.locale,
        town_city = mu.town_city,
        district = mu.district,
        county = mu.county,
        ppd_category = mu.ppd_category,
        record_type = mu.record_type
    FROM ducklake_land_registry.monthly_updates AS mu
    WHERE ducklake_land_registry.price_paid_raw.id = mu.id AND mu.record_type = 'C';
    """
)

# %% [markdown]
# So adopt a delete and then insert approach.

# %%
duckdb.sql(
    f"""
    DELETE FROM ducklake_land_registry.price_paid_raw
    WHERE id IN (SELECT id FROM ducklake_land_registry.monthly_updates WHERE record_type = 'C');
    """
)

# %%
duckdb.sql(
    f"""
    INSERT INTO ducklake_land_registry.price_paid_raw
    SELECT * FROM ducklake_land_registry.monthly_updates
    WHERE record_type = 'C';
    """
)

# %%
duckdb.sql(
    f"""
    FROM ducklake_snapshots('ducklake_land_registry');
    """
)
# Out:
# ┌─────────────┬───────────────────────────────┬────────────────┬───────────────────────────────────────────────────────────────────┬─────────┬────────────────┬───────────────────┐
# │ snapshot_id │         snapshot_time         │ schema_version │                              changes                              │ author  │ commit_message │ commit_extra_info │
# │    int64    │   timestamp with time zone    │     int64      │                      map(varchar, varchar[])                      │ varchar │    varchar     │      varchar      │
# ├─────────────┼───────────────────────────────┼────────────────┼───────────────────────────────────────────────────────────────────┼─────────┼────────────────┼───────────────────┤
# │           0 │ 2025-12-02 09:47:04.786537+00 │              0 │ {schemas_created=[main]}                                          │ NULL    │ NULL           │ NULL              │
# │           1 │ 2025-12-02 09:49:38.251125+00 │              1 │ {tables_created=[main.price_paid_raw], tables_inserted_into=[1]}  │ NULL    │ NULL           │ NULL              │
# │           2 │ 2025-12-02 09:49:43.427665+00 │              2 │ {tables_created=[main.monthly_updates], tables_inserted_into=[2]} │ NULL    │ NULL           │ NULL              │
# │           3 │ 2025-12-02 09:49:43.652845+00 │              2 │ {tables_inserted_into=[1]}                                        │ NULL    │ NULL           │ NULL              │
# │           4 │ 2025-12-02 09:49:43.836903+00 │              2 │ {tables_inserted_into=[1], tables_deleted_from=[1]}               │ NULL    │ NULL           │ NULL              │
# │           5 │ 2025-12-02 09:49:43.91386+00  │              2 │ {tables_deleted_from=[1]}                                         │ NULL    │ NULL           │ NULL              │
# │           6 │ 2025-12-02 09:49:43.948576+00 │              2 │ {tables_inserted_into=[1]}                                        │ NULL    │ NULL           │ NULL              │
# └─────────────┴───────────────────────────────┴────────────────┴───────────────────────────────────────────────────────────────────┴─────────┴────────────────┴───────────────────┘
